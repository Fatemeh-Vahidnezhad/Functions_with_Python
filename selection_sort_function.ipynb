# %%
import pandas as pd

# %%
def selection_sort(lst):
    for i in range(0,len(lst)-1):
        print("i=", i)
        minindex = i
        
        print("minindex, lst[minindex]", minindex, lst[minindex])
        for j in range(i+1,len(lst)):
            print("j, len(lst) =",j, len(lst))
            print("lst[minindex] , lstj:", lst[minindex], lst[j])
            if lst[minindex] > lst[j]:
                print("yes, lst[minindex] > lstj:", lst[minindex], lst[j])
                #minindex = j
                lst[minindex] , lst[j] = lst[j], lst[minindex]  
                print("lst[minindex], lst[j]",lst[minindex], lst[j])
            print(lst)
            print("\n")
            
    return lst


mylist = [5,2,1,0,9,75,97,-4]
selection_sort(mylist)
# Out:
# i= 0
# minindex, lst[minindex] 0 5
# j, len(lst) = 1 8
# lst[minindex] , lstj: 5 2
# yes, lst[minindex] > lstj: 5 2
# lst[minindex], lst[j] 2 5
# [2, 5, 1, 0, 9, 75, 97, -4]
#
#
# j, len(lst) = 2 8
# lst[minindex] , lstj: 2 1
# yes, lst[minindex] > lstj: 2 1
# lst[minindex], lst[j] 1 2
# [1, 5, 2, 0, 9, 75, 97, -4]
#
#
# j, len(lst) = 3 8
# lst[minindex] , lstj: 1 0
# yes, lst[minindex] > lstj: 1 0
# lst[minindex], lst[j] 0 1
# [0, 5, 2, 1, 9, 75, 97, -4]
#
#
# j, len(lst) = 4 8
# lst[minindex] , lstj: 0 9
# [0, 5, 2, 1, 9, 75, 97, -4]
#
#
# j, len(lst) = 5 8
# lst[minindex] , lstj: 0 75
# [0, 5, 2, 1, 9, 75, 97, -4]
#
#
# j, len(lst) = 6 8
# lst[minindex] , lstj: 0 97
# [0, 5, 2, 1, 9, 75, 97, -4]
#
#
# j, len(lst) = 7 8
# lst[minindex] , lstj: 0 -4
# yes, lst[minindex] > lstj: 0 -4
# lst[minindex], lst[j] -4 0
# [-4, 5, 2, 1, 9, 75, 97, 0]
#
#
# i= 1
# minindex, lst[minindex] 1 5
# j, len(lst) = 2 8
# lst[minindex] , lstj: 5 2
# yes, lst[minindex] > lstj: 5 2
# ...

# %%
def selection_sort(lst):
    for i in range(0,len(lst)-1):
        #considering first row as a minimum value in the list:
        minindex = i
        for j in range(i+1,len(lst)):
            if lst[minindex] > lst[j]:
                lst[minindex] , lst[j] = lst[j], lst[minindex] 
            
    return lst


mylist = [5,2,1,0,9,75,97,-4]
selection_sort(mylist)
# Out:
# [-4, 0, 1, 2, 5, 9, 75, 97]
